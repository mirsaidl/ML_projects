# %% [markdown]
# Customer churn, or customer attrition, is a critical issue in business where customers stop engaging with a company's products or services. Identifying customer churn is crucial for businesses as it helps them understand why customers leave and take proactive measures to retain them.
#
# In this scenario, we can analyze customer data from the online store to predict customer churn. By examining various factors such as purchase history, frequency of visits, feedback, demographics, etc., we can build predictive models to determine the likelihood of a customer churning. These models can then be used to identify at-risk customers and implement targeted retention strategies, such as personalized offers, improved customer service, loyalty programs, etc., to prevent them from leaving.
#
# By actively monitoring and addressing customer churn, businesses can improve customer retention rates, enhance customer satisfaction, and ultimately, drive long-term profitability.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from xgboost import XGBClassifier

from sklearn.pipeline import Pipeline
from sklearn import metrics

# %%
url="https://github.com/anvarnarz/praktikum_datasets/blob/main/E-Commerce-Dataset.xlsx?raw=true"
df = pd.read_excel(url, sheet_name="E Comm")
df.head()
# Out:
#    CustomerID  Churn  Tenure PreferredLoginDevice  CityTier  WarehouseToHome  \
# 0       50001      1     4.0         Mobile Phone         3              6.0
# 1       50002      1     NaN                Phone         1              8.0
# 2       50003      1     NaN                Phone         1             30.0
# 3       50004      1     0.0                Phone         3             15.0
# 4       50005      1     0.0                Phone         1             12.0
#
#   PreferredPaymentMode  Gender  HourSpendOnApp  NumberOfDeviceRegistered  \
# 0           Debit Card  Female             3.0                         3
# 1                  UPI    Male             3.0                         4
# 2           Debit Card    Male             2.0                         4
# 3           Debit Card    Male             2.0                         4
# 4                   CC    Male             NaN                         3
#
# ...

# %%
# Shape
df.shape
# big enough to work on
# Out:
# (5630, 20)

# %%
description = pd.read_excel(url, sheet_name="Data Dict", header=1, usecols=[1,2,3])
description
# Out:
#       Data                     Variable  \
# 0   E Comm                   CustomerID
# 1   E Comm                        Churn
# 2   E Comm                       Tenure
# 3   E Comm         PreferredLoginDevice
# 4   E Comm                     CityTier
# 5   E Comm              WarehouseToHome
# 6   E Comm         PreferredPaymentMode
# 7   E Comm                       Gender
# 8   E Comm               HourSpendOnApp
# 9   E Comm     NumberOfDeviceRegistered
# 10  E Comm             PreferedOrderCat
# 11  E Comm            SatisfactionScore
# 12  E Comm                MaritalStatus
# 13  E Comm              NumberOfAddress
# 14  E Comm                     Complain
# 15  E Comm  OrderAmountHikeFromlastYear
# 16  E Comm                   CouponUsed
# 17  E Comm                   OrderCount
# 18  E Comm            DaySinceLastOrder
# 19  E Comm               CashbackAmount
#
#                                           Discerption
# 0                                  Unique customer ID
# ...

# %% [markdown]
# # Data analysis

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5630 entries, 0 to 5629
# Data columns (total 20 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   CustomerID                   5630 non-null   int64
#  1   Churn                        5630 non-null   int64
#  2   Tenure                       5366 non-null   float64
#  3   PreferredLoginDevice         5630 non-null   object
#  4   CityTier                     5630 non-null   int64
#  5   WarehouseToHome              5379 non-null   float64
#  6   PreferredPaymentMode         5630 non-null   object
#  7   Gender                       5630 non-null   object
#  8   HourSpendOnApp               5375 non-null   float64
#  9   NumberOfDeviceRegistered     5630 non-null   int64
#  10  PreferedOrderCat             5630 non-null   object
#  11  SatisfactionScore            5630 non-null   int64
#  12  MaritalStatus                5630 non-null   object
# ...

# %%
df.describe()
# Out:
#          CustomerID        Churn       Tenure     CityTier  WarehouseToHome  \
# count   5630.000000  5630.000000  5366.000000  5630.000000      5379.000000
# mean   52815.500000     0.168384    10.189899     1.654707        15.639896
# std     1625.385339     0.374240     8.557241     0.915389         8.531475
# min    50001.000000     0.000000     0.000000     1.000000         5.000000
# 25%    51408.250000     0.000000     2.000000     1.000000         9.000000
# 50%    52815.500000     0.000000     9.000000     1.000000        14.000000
# 75%    54222.750000     0.000000    16.000000     3.000000        20.000000
# max    55630.000000     1.000000    61.000000     3.000000       127.000000
#
#        HourSpendOnApp  NumberOfDeviceRegistered  SatisfactionScore  \
# count     5375.000000               5630.000000        5630.000000
# mean         2.931535                  3.688988           3.066785
# std          0.721926                  1.023999           1.380194
# ...

# %%
churn_rate = df.Churn.value_counts()/len(df) * 100

# %%
plt.figure(figsize=(5,5))
plt.pie(churn_rate, labels=['Churn', 'No Churn'])
plt.show()

# %%
fig, axes = plt.subplots(1,3, figsize=(15,5))

sns.countplot(x='Gender', hue='Churn', palette='viridis', data=df, ax=axes[0])
axes[0].set_title('Churn according to gender')

sns.countplot(x='MaritalStatus', hue='Churn', palette='hls', data=df, ax=axes[1])
axes[1].set_title("Churn according to Martial Status")

sns.countplot(x='Complain', hue='Churn', palette='husl', data=df, ax=axes[2])
axes[1].set_title("Complains")

plt.show()

# %%
fig, axes = plt.subplots(1,3, figsize=(15,5))

# Tenure
sns.histplot(x="Tenure", data=df, ax=axes[0])

#OrderCount
sns.histplot(x="OrderCount", data=df, ax=axes[1])

# Cashback
sns.histplot(x="CashbackAmount", data=df, ax=axes[2])

plt.show()

# %%
numeric_df = df.select_dtypes(include=['number'])
# Calculate correlation matrix
correlation_matrix = numeric_df.corrwith(numeric_df.Churn).abs().sort_values(ascending=False)
correlation_matrix
# Out:
# Churn                          1.000000
# Tenure                         0.349408
# Complain                       0.250188
# DaySinceLastOrder              0.160757
# CashbackAmount                 0.154118
# NumberOfDeviceRegistered       0.107939
# SatisfactionScore              0.105481
# CityTier                       0.084703
# WarehouseToHome                0.076630
# NumberOfAddress                0.043931
# OrderCount                     0.028697
# CustomerID                     0.019083
# HourSpendOnApp                 0.018675
# OrderAmountHikeFromlastYear    0.010058
# CouponUsed                     0.008264
# dtype: float64

# %% [markdown]
# # Data Cleaning

# %%
# check nulls 
print('Column nulls: \n', df.isnull().sum())
print('Overall nulls: ', df.isnull().sum().sum())
# Out:
# Column nulls:
#  CustomerID                       0
# Churn                            0
# Tenure                         264
# PreferredLoginDevice             0
# CityTier                         0
# WarehouseToHome                251
# PreferredPaymentMode             0
# Gender                           0
# HourSpendOnApp                 255
# NumberOfDeviceRegistered         0
# PreferedOrderCat                 0
# SatisfactionScore                0
# MaritalStatus                    0
# NumberOfAddress                  0
# Complain                         0
# OrderAmountHikeFromlastYear    265
# CouponUsed                     256
# OrderCount                     258
# DaySinceLastOrder              307
# CashbackAmount                   0
# dtype: int64
# Overall nulls:  1856

# %%
# Drop columns that has less corr with Churn (less than 15 %) this way we can reduce NaN values 
data = df[['Churn','Tenure','Complain','DaySinceLastOrder','CashbackAmount','MaritalStatus','Gender']].copy()

# %%
# Dropna()
data.dropna(inplace=True)

# %% [markdown]
# # Preparation for Machine Learning

# %%
# encoding
encoded = pd.get_dummies(data)
encoded.replace({False:0, True:1}, inplace=True)

# %%
encoded.head()
# Out:
#    Churn  Tenure  Complain  DaySinceLastOrder  CashbackAmount  \
# 0      1     4.0         1                5.0          159.93
# 3      1     0.0         0                3.0          134.07
# 4      1     0.0         0                3.0          129.60
# 5      1     0.0         1                7.0          139.19
# 8      1    13.0         1                2.0          126.83
#
#    MaritalStatus_Divorced  MaritalStatus_Married  MaritalStatus_Single  \
# 0                       0                      0                     1
# 3                       0                      0                     1
# 4                       0                      0                     1
# 5                       0                      0                     1
# 8                       1                      0                     0
#
#    Gender_Female  Gender_Male
# 0              1            0
# 3              0            1
# 4              0            1
# 5              1            0
# ...

# %%
x = encoded.drop("Churn", axis=1)
y = encoded['Churn']

# %%
scaler = StandardScaler()
x = scaler.fit_transform(x)

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2, stratify=y, random_state=30)

# %% [markdown]
# # ML

# %% [markdown]
# ### Logistic Regression

# %%
# Create model (training)
log_reg = LogisticRegression()
log_reg.fit(x_train,y_train)

# Evaluate model
y_pred = log_reg.predict(x_test)
print(metrics.classification_report(y_test, y_pred))
print("Model accuracy: ", metrics.accuracy_score(y_test, y_pred))

# Confusion matrix
conf_mat = metrics.confusion_matrix(y_test, y_pred)
sns.heatmap(conf_mat, annot=True, fmt='g')

# Roc Curve
fpr, tpr, thresholds = metrics.roc_curve(y_test, y_pred)
roc_auc = metrics.auc(fpr,tpr)
display = metrics.RocCurveDisplay(fpr=fpr, tpr=tpr, roc_auc=roc_auc, estimator_name='ROC curve')
display.plot()
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.96      0.93       849
#            1       0.68      0.42      0.52       163
#
#     accuracy                           0.87      1012
#    macro avg       0.79      0.69      0.72      1012
# weighted avg       0.86      0.87      0.86      1012
#
# Model accuracy:  0.8745059288537549

# %% [markdown]
# ### Support Vector Machines

# %%
# Create model (training)
svcmod = SVC()
svcmod.fit(x_train,y_train)

# Evaluate model
y_pred = svcmod.predict(x_test)
print(metrics.classification_report(y_test, y_pred))
print("Model accuracy: ", metrics.accuracy_score(y_test, y_pred))

# Confusion matrix
conf_mat = metrics.confusion_matrix(y_test, y_pred)
sns.heatmap(conf_mat, annot=True, fmt='g')

# Roc Curve
fpr, tpr, thresholds = metrics.roc_curve(y_test, y_pred)
roc_auc = metrics.auc(fpr,tpr)
display = metrics.RocCurveDisplay(fpr=fpr, tpr=tpr, roc_auc=roc_auc, estimator_name='ROC curve')
display.plot()
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.97      0.93       849
#            1       0.72      0.36      0.48       163
#
#     accuracy                           0.87      1012
#    macro avg       0.80      0.66      0.70      1012
# weighted avg       0.86      0.87      0.86      1012
#
# Model accuracy:  0.8735177865612648

# %% [markdown]
# # Decision Tree

# %%
# Create model (training)
tree = DecisionTreeClassifier()
tree.fit(x_train,y_train)

# Evaluate model
y_pred = tree.predict(x_test)
print(metrics.classification_report(y_test, y_pred))
print("Model accuracy: ", metrics.accuracy_score(y_test, y_pred))

# Confusion matrix
conf_mat = metrics.confusion_matrix(y_test, y_pred)
sns.heatmap(conf_mat, annot=True, fmt='g')

# Roc Curve
fpr, tpr, thresholds = metrics.roc_curve(y_test, y_pred)
roc_auc = metrics.auc(fpr,tpr)
display = metrics.RocCurveDisplay(fpr=fpr, tpr=tpr, roc_auc=roc_auc, estimator_name='ROC curve')
display.plot()
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97       849
#            1       0.86      0.83      0.84       163
#
#     accuracy                           0.95      1012
#    macro avg       0.91      0.90      0.91      1012
# weighted avg       0.95      0.95      0.95      1012
#
# Model accuracy:  0.950592885375494

# %%
cols = encoded.drop('Churn', axis=1).columns

plt.figure(figsize=(30,20))
plot_tree(tree, filled=True)
plt.show()

# %% [markdown]
# ### Random Forest

# %%
# Create model (training)
rfors = RandomForestClassifier()
rfors.fit(x_train,y_train)

# Evaluate model
y_pred = rfors.predict(x_test)
print(metrics.classification_report(y_test, y_pred))
print("Model accuracy: ", metrics.accuracy_score(y_test, y_pred))

# Confusion matrix
conf_mat = metrics.confusion_matrix(y_test, y_pred)
sns.heatmap(conf_mat, annot=True, fmt='g')

# Roc Curve
fpr, tpr, thresholds = metrics.roc_curve(y_test, y_pred)
roc_auc = metrics.auc(fpr,tpr)
display = metrics.RocCurveDisplay(fpr=fpr, tpr=tpr, roc_auc=roc_auc, estimator_name='ROC curve')
display.plot()
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.97      0.96       849
#            1       0.83      0.75      0.79       163
#
#     accuracy                           0.94      1012
#    macro avg       0.89      0.86      0.88      1012
# weighted avg       0.93      0.94      0.93      1012
#
# Model accuracy:  0.9357707509881423

# %% [markdown]
# # XGBoost

# %%
# Create model (training)
xgboost = XGBClassifier()
xgboost.fit(x_train,y_train)

# Evaluate model
y_pred = xgboost.predict(x_test)
print(metrics.classification_report(y_test, y_pred))
print("Model accuracy: ", metrics.accuracy_score(y_test, y_pred))

# Confusion matrix
conf_mat = metrics.confusion_matrix(y_test, y_pred)
sns.heatmap(conf_mat, annot=True, fmt='g')

# Roc Curve
fpr, tpr, thresholds = metrics.roc_curve(y_test, y_pred)
roc_auc = metrics.auc(fpr,tpr)
display = metrics.RocCurveDisplay(fpr=fpr, tpr=tpr, roc_auc=roc_auc, estimator_name='ROC curve')
display.plot()
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.96      0.95       849
#            1       0.77      0.72      0.75       163
#
#     accuracy                           0.92      1012
#    macro avg       0.86      0.84      0.85      1012
# weighted avg       0.92      0.92      0.92      1012
#
# Model accuracy:  0.9209486166007905

# %% [markdown]
# So, We went through all ML Classification algorithms , find out that most
# accurate classifier for this data is DecisionTree model. Let's save it and
# finish project. Thank you!

# %%
from joblib import dump
dump(tree, 'decisiontree.jbl')
# Out:
# ['decisiontree.jbl']
